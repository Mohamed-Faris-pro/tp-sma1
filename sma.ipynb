# %%
from langchain_openai import ChatOpenAI
from langchain.messages import SystemMessage, HumanMessage, AIMessage
from dotenv.ipython import load_dotenv
from IPython.display import Markdown
import tiktoken

# %%
# Charger les variables d'environnement OPENAI_API_KEY du ficher .env
load_dotenv(override=True)
# os.environ['OPENAI_API_KEY']="sk-proj-gBJaJ8...."
# Out:
# True

# %%
#encoding = tiktoken.get_encoding("cl200k_base")
encoding = tiktoken.encoding_for_model("gpt-4o")
print(encoding.name)
system_message =""" 
Perform Sentiment analysis of the review presented in the user message.
The result should be positive or negative. Do not justify your response
"""
tokens = encoding.encode(system_message)
# Out:
# o200k_base

# %%
print(len(tokens))
print(tokens)
for token in tokens:
    print(encoding.decode_single_token_bytes(token=token),end="")
# Out:
# 28
# [793, 73751, 31712, 2581, 8450, 328, 290, 3358, 13392, 306, 290, 1825, 3176, 558, 976, 1534, 1757, 413, 8841, 503, 12626, 13, 3756, 625, 14883, 634, 3322, 198]
# b' \n'b'Perform'b' Sent'b'iment'b' analysis'b' of'b' the'b' review'b' presented'b' in'b' the'b' user'b' message'b'.\n'b'The'b' result'b' should'b' be'b' positive'b' or'b' negative'b'.'b' Do'b' not'b' justify'b' your'b' response'b'\n'

# %%
def num_tokens_from_string(string: str, encoding_name: str = "o200k_base") -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
num_tokens_from_string("tiktoken is great!")
# Out:
# 6

# %%
model = ChatOpenAI(
    model="gpt-5.2", temperature=0
    )

# %%
response = model.invoke([
    {"role":"system", "content":"You are a helpful assistant. The output should be in Markdown"},
    {"role":"user","content":"C'est quoi un Agent AI"}
])

# %%
# Même chose
response = model.invoke([
    SystemMessage("You are a helpful assistant. The output should be in Markdown"),
    HumanMessage("C'est quoi un Agent AI")]
    )

# %%
print(display(Markdown(response.content)))
# Out:
# Un **Agent IA (Agent AI)**, c’est un programme basé sur l’intelligence artificielle qui peut **agir de manière autonome** pour atteindre un objectif, en enchaînant des étapes comme **comprendre une demande, planifier, utiliser des outils, exécuter des actions et s’adapter** selon les résultats.
#
# ### Ce qui le différencie d’un simple chatbot
# - **Chatbot classique** : répond surtout avec du texte, de façon réactive.
# - **Agent IA** : peut **prendre des décisions et faire des actions** (ex. lancer une recherche, écrire et exécuter du code, appeler une API, créer un document, réserver, envoyer un message), souvent en plusieurs étapes.
#
# ### Comment ça marche (simplifié)
# 1. **Objectif** : “Organise-moi un voyage à Lyon ce week-end”.
# 2. **Plan** : transport, hébergement, activités, budget.
# 3. **Actions / outils** : recherche web, comparaison, calendrier, email, etc.
# 4. **Vérifications** : contraintes (prix, horaires), ajustements.
# 5. **Résultat** : proposition + éventuellement exécution (si autorisé).
#
# ### Exemples d’agents IA
# - Un agent qui **trie et répond aux emails** selon des règles.
# - Un agent “data” qui **analyse un fichier CSV**, produit un rapport et des graphiques.
# - Un agent “dev” qui **corrige un bug**, lance des tests et propose un patch.
# - Un agent service client qui **résout un ticket**, consulte la base de connaissance et met à jour le CRM.
#
# ### Points importants
# - **Autonomie contrôlée** : souvent on limite ce qu’il peut faire (droits, validations).
# - **Risques** : erreurs, actions non souhaitées, données sensibles → besoin de garde-fous.
# - **Mémoire / contexte** : certains agents gardent des infos pour mieux suivre une tâche.
#
# Si tu me dis **dans quel contexte** (travail, étude, entreprise, dev…), je peux te donner des exemples d’agents IA adaptés et comment en créer un.
# None

# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="llama3.2")

# %%
response = llm.invoke([
    SystemMessage("You are a helpful assistant. The output should be in Markdown"),
    HumanMessage("C'est quoi un Agent AI")
])

# %%
print(display(Markdown(response.content)))
# Out:
# **Découvrez les Agents AI**
#
# Un Agent AI (Agent Artificiel ou Intelligent Artificiel) est un système informatique conçu pour simuler des comportements intelligents, tels que la pensée, l'apprentissage et la prise de décision. Les Agents AI sont conçus pour agir dans un environnement donné, en tenant compte de divers facteurs tels que les données, les objectifs et les contraintes.
#
# **Fonctionnement des Agents AI**
#
# Les Agents AI fonctionnent en utilisant des algorithmes et des techniques telles que :
#
# *   **Apprentissage**: les Agents AI apprennent à partir de données et d'expériences pour améliorer leurs performances et leurs décisions.
# *   **Prise de décision**: les Agents AI prennent des décisions en fonction de leurs objectifs, de leurs contraintes et de leurs ressources.
# *   **Interaction avec l'environnement**: les Agents AI interagissent avec leur environnement pour collecter des informations, réaliser des actions et évaluer leurs résultats.
#
# **Types d'Agents AI**
#
# Il existe plusieurs types d'Agents AI, notamment :
#
# *   **Agents basés sur l'apprentissage** : ces Agents AI apprennent à partir de données et d'expériences pour améliorer leurs performances.
# *   **Agents basés sur la recherche** : ces Agents AI recherchent des solutions à des problèmes et des objectifs spécifiques.
# *   **Agents basés sur la réaction** : ces Agents AI réagissent à des événements et des situations pour prendre des décisions et agir.
#
# **Exemples d'Agents AI**
#
# Les Agents AI sont utilisés dans de nombreuses applications, notamment :
#
# *   **Assistants virtuels** : tels que Siri, Alexa et Google Assistant, qui utilisent des Agents AI pour prendre des décisions et agir en fonction de la demande utilisateur.
# *   **Véhicules autonomes** : qui utilisent des Agents AI pour naviguer et prendre des décisions en fonction de l'environnement et des réglementations.
# *   **Systèmes de recommandation** : tels que Netflix, qui utilisent des Agents AI pour recommander des contenus en fonction des préférences utilisateur.
#
# **Avantages des Agents AI**
#
# Les Agents AI offrent de nombreux avantages, notamment :
#
# *   **Amélioration de la précision** : les Agents AI peuvent prendre des décisions plus précises et plus rapides que les humains.
# *   **Réduction des coûts** : les Agents AI peuvent réduire les coûts en automatisant des tâches et en réduisant les erreurs.
# *   **Amélioration de l'efficacité** : les Agents AI peuvent améliorer l'efficacité en optimisant les processus et en réduisant les temps de traitement.
#
# En résumé, les Agents AI sont des systèmes informatiques conçus pour simuler des comportements intelligents et prendre des décisions en fonction de leur environnement. Ils sont utilisés dans de nombreuses applications et offrent de nombreux avantages.
# None

# %%
# Charger la variable d'environnement GROQ_API_KEY du fichier .env
load_dotenv(override=True)
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm3 = ChatGroq(model="openai/gpt-oss-120b")

# %%
resp3 = llm.invoke([
    SystemMessage("You are a helpful assistant. The output should be in Markdown"),
    HumanMessage("C'est quoi un Agent AI")
])

# %%
print(display(Markdown(resp3.content)))
# Out:
# # Qu'est-ce qu'un Agent AI ?
#
# Un Agent AI (Autonome Intelligence Artificielle) est un programme informatique conçu pour simuler les capacités d'un être humain pour prendre des décisions, résoudre des problèmes et interagir avec son environnement de manière autonome. Les agents AI sont conçus pour apprendre, se rappeler et adapter leur comportement en fonction de leurs expériences et de leur environnement.
#
# ## Caractéristiques clés d'un Agent AI
#
# Voici quelques-unes des caractéristiques clés d'un Agent AI :
#
# * **Auto-organisation** : les agents AI peuvent se mettre en place pour résoudre des problèmes sans nécessiter d'entrée de données manuelle.
# * **Apprentissage** : les agents AI peuvent apprendre à partir de leurs expériences et de leurs erreurs pour améliorer leurs performances.
# * **Rappel** : les agents AI peuvent se rappeler des informations et des expériences précédentes pour prendre des décisions éclairées.
# * **Autonomie** : les agents AI peuvent prendre des décisions et agir sans nécessaire intervention humaine.
#
# ## Types d'agents AI
#
# Il existe plusieurs types d'agents AI, notamment :
#
# * **Agent de récompense** : qui prend des décisions en fonction de récompenses ou de rétroactions positives.
# * **Agent de stratégie** : qui utilise des stratégies de game-playing pour résoudre des problèmes.
# * **Agent de langage** : qui utilise des langages naturels pour communiquer avec les humains ou avec d'autres agents.
#
# ## Applications de l'Agent AI
#
# Les agents AI ont de nombreuses applications dans différents domaines, notamment :
#
# * **Connaissance artificielle** : les agents AI peuvent aider les humains à résoudre des problèmes de connaissance et de compréhension.
# * **Robotique** : les agents AI peuvent contrôler les robots pour leur permettre de naviguer et de manœuvrer dans des environnements complexes.
# * **Gouvernance** : les agents AI peuvent aider les humains à prendre des décisions éclairées et à résoudre des problèmes de gouvernance.
#
# En résumé, les agents AI sont des programmes informatiques conçus pour simuler les capacités d'un être humain pour prendre des décisions, résoudre des problèmes et interagir avec son environnement de manière autonome. Ils ont de nombreuses applications dans différents domaines et continuent à évoluer pour devenir encore plus sophistiqués.
# None

# %%
llm4 = ChatOpenAI(model="gpt-5.2")
llm_with_tools = llm4.bind_tools([
    {"type":"image_generation", "quality":"high"}
    ])

# %%
resp4 = llm_with_tools.invoke(input=[
    HumanMessage("Je veux une photo d'un chat qui code du java")
])

# %%
from IPython.display import Image
import base64

# %%
Image(base64.b64decode(resp4.content_blocks[0]['base64']))

# %%
path = "rag.png"

# %%
llm5 = ChatOpenAI(model="gpt-5.2")

# %%
# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# %%
img = encode_image(path)

# %%
resp5 = llm5.invoke(input=[
    HumanMessage(content=[
        {"type":"text","text":"Qu'est ce que tu vois dans cette image"},
        {"type":"image_url", "image_url": {"url": f"data:image/png;base64,{img}"}}
    ])])

# %%
print(display(Markdown(resp5.content)))
# Out:
# Je vois un schéma explicatif d’une application **RAG (Retrieval-Augmented Generation)** :
#
# - Un **PDF** est **découpé (split)** en **chunks** (C1, C2, C3).
# - Chaque chunk est transformé en **embeddings** (vecteurs numériques, ex. 0.43, 0.11, 0.76, -0.5).
# - Ces embeddings sont stockés dans une **base de données** (type base vectorielle).
# - L’**utilisateur** envoie une **query** à l’**app RAG**.
# - L’app interroge la base pour récupérer du **contexte** pertinent, puis envoie au **LLM** : **System message + Query + Context** via **HTTP/JSON**.
# - Le **LLM** renvoie une **réponse**, qui est ensuite renvoyée à l’utilisateur.
#
# En haut à droite, il y a aussi la **photo d’une personne** (portrait) intégrée au visuel.
# None

# %%
system_message = """
Effectuez une analyse de sentiments basée sur les aspects des avis concernant les ordinateurs portables présentés en entrée.
Chaque avis peut comporter un ou plusieurs des aspects suivants : screen, keyboard et pad.
Pour chaque avis présenté en entrée :
- Identifiez la présence d'au moins un des trois aspects (screen, keyboard, pad).
- Attribuez une polarité de sentiment (positive, negative ou neutral) à chaque aspect. Organisez votre réponse dans un objet JSON avec les en-têtes suivants :
  - category:[liste des aspects]
  - polarity:[liste des polarités correspondantes pour chaque aspect]
Si l'un des aspects n'est pas présent dans l'avis de l'utilisateur, tu supposes que la polarité est neutre 
"""

# %%
zeroshot_prompt = [
  {"role": "system", "content": system_message},
  {"role": "user", "content": """
       L'écran est très bon, mais je n'ai pas aimé la souris. le clavier Ma fih Maytchaf
       """}
]

# %%
llm = ChatOpenAI(model="gpt-5.2")
resp = llm.invoke(input=zeroshot_prompt)

# %%
print(resp.content)
# Out:
# ```json
# {
#   "category": ["screen", "keyboard", "pad"],
#   "polarity": ["positive", "negative", "negative"]
# }
# ```

# %%
resp_text_json = resp.content.replace("```json","").replace("```","")

# %%
print (resp_text_json)
# Out:
# {
#   "category": ["screen", "keyboard", "pad"],
#   "polarity": ["positive", "negative", "negative"]
# }

# %%
import json

# %%
result = json.loads(resp_text_json)

# %%
type(result)
# Out:
# dict

# %%
result
# Out:
# {'category': ['screen', 'keyboard', 'pad'],
#  'polarity': ['positive', 'negative', 'negative']}

# %%
print(result['category'])
# Out:
# ['screen', 'keyboard', 'pad']

# %%
print(result['polarity'][0])
# Out:
# positive
